# %%
# Abhishek Gaba
# Python Final Project

# %%
# Calling Python libraries important for the code below
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/Users/Abhishekgaba/Desktop/HBO.csv')

# %%
df
# Out:
#              id                                           title   type  \
# 0      tm155702                                The Wizard of Oz  MOVIE
# 1       tm83648                                    Citizen Kane  MOVIE
# 2       tm77588                                      Casablanca  MOVIE
# 3       tm82363                                   The Big Sleep  MOVIE
# 4       tm84701                              The Maltese Falcon  MOVIE
# ...         ...                                             ...    ...
# 3289  tm1082718  Romeo Santos: Utopia Live from MetLife Stadium  MOVIE
# 3290  tm1067128                                       Algo Azul  MOVIE
# 3291  tm1121489                        Entre Nos: What She Said  MOVIE
# 3292  tm1121486                        Entre Nos: The Winners 2  MOVIE
# 3293   tm989132                             The Infamous Future  MOVIE
#
#                                             description  release_year  \
# ...

# %%
df.set_index('title')
# Out:
#                                                        id   type  \
# title
# The Wizard of Oz                                 tm155702  MOVIE
# Citizen Kane                                      tm83648  MOVIE
# Casablanca                                        tm77588  MOVIE
# The Big Sleep                                     tm82363  MOVIE
# The Maltese Falcon                                tm84701  MOVIE
# ...                                                   ...    ...
# Romeo Santos: Utopia Live from MetLife Stadium  tm1082718  MOVIE
# Algo Azul                                       tm1067128  MOVIE
# Entre Nos: What She Said                        tm1121489  MOVIE
# Entre Nos: The Winners 2                        tm1121486  MOVIE
# The Infamous Future                              tm989132  MOVIE
#
#                                                                                       description  \
# title
# ...

# %%
ratings = df['age_certification'].value_counts()

# %%
ratings.plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
types = df['type'].value_counts()
types.plot(kind='pie')
# Out:
# <AxesSubplot:ylabel='type'>

# %%
df2 = pd.read_csv('/Users/Abhishekgaba/Desktop/disney_plus_shows.csv')

# %%
df2
# Out:
#        imdb_id                                       title  \
# 0    tt0147800                  10 Things I Hate About You
# 1    tt7019028                        101 Dalmatian Street
# 2    tt0115433                              101 Dalmatians
# 3    tt0324941  101 Dalmatians 2: Patch's London Adventure
# 4    tt0211181                              102 Dalmatians
# ..         ...                                         ...
# 987  tt3544734                                      Zapped
# 988  tt0186726             Zenon: Girl of the 21st Century
# 989  tt0271271                           Zenon: The Zequel
# 990  tt0379060                                   Zenon: Z3
# 991  tt2948356                                    Zootopia
#
#                                                   plot    type  rated   year  \
# 0    A pretty, popular teenager can't go out on a d...   movie  PG-13   1999
# 1    This series follows the lives of Delilah and D...  series    NaN  2018–
# ...

# %%
df2.set_index('title')
# Out:
#                                               imdb_id  \
# title
# 10 Things I Hate About You                  tt0147800
# 101 Dalmatian Street                        tt7019028
# 101 Dalmatians                              tt0115433
# 101 Dalmatians 2: Patch's London Adventure  tt0324941
# 102 Dalmatians                              tt0211181
# ...                                               ...
# Zapped                                      tt3544734
# Zenon: Girl of the 21st Century             tt0186726
# Zenon: The Zequel                           tt0271271
# Zenon: Z3                                   tt0379060
# Zootopia                                    tt2948356
#
#                                                                                          plot  \
# title
# 10 Things I Hate About You                  A pretty, popular teenager can't go out on a d...
# 101 Dalmatian Street                        This series follows the lives of Delilah and D...
# ...

# %%
ratings2 = df2['rated'].value_counts()
ratings2
# Out:
# G            207
# PG           155
# TV-G         132
# Approved      52
# TV-PG         41
# TV-Y7         41
# PG-13         37
# TV-Y          34
# Not Rated     16
# APPROVED       8
# TV-14          4
# Passed         4
# TV-Y7-FV       3
# UNRATED        3
# Unrated        2
# PASSED         2
# NOT RATED      1
# Name: rated, dtype: int64

# %%
ratings2.plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
types2 = df2['type'].value_counts()
types2.plot(kind='pie')
# Out:
# <AxesSubplot:ylabel='type'>

# %%
# Random selecter 
platform = input("What service do you want to use? Enter D for Disney Plus or H for HBO Max ")

while platform == 'D' or 'H':

    if platform == 'D':
        print('Ok, you want to use Disney Plus')
        Disney_choice = (input('Do you want to watch a series or a movie? Type out one of those choices'))
        break


    if platform =='H':
        print('Ok, you want to use HBO Max')
        HBO_choice = (input('Do you want to watch a show or a movie? Type out one of those choices'))
        break
    else:
        print('Invalid choice, try again')
        platform = input("What service do you want to use? Enter D for Disney Plus or H for HBO Max ")
# Out:
# What service do you want to use? Enter D for Disney Plus or H for HBO Max S
# Invalid choice, try again
# What service do you want to use? Enter D for Disney Plus or H for HBO Max D
# Ok, you want to use Disney Plus
# Do you want to watch a series or a movie? Type out one of those choicesmovie

# %%
if platform == 'D' and Disney_choice == 'series':
    Disney_shows = df2['title'][df2['type'] == 'series']
    print('Here is your randomly selected series to watch:')

# %%
if platform == 'D' and Disney_choice == 'series':
    print(Disney_shows.sample())

# %%
if platform == "D" and Disney_choice == 'movie':
    Disney_movies = df2['title'][df2['type'] == 'movie']
    print('Here is your randomly selected movie to watch:')
# Out:
# Here is your randomly selected movie to watch:

# %%
if platform == "D" and Disney_choice == 'movie':
    print(Disney_movies.sample())
# Out:
# 700    Society Dog Show
# Name: title, dtype: object

# %%
if platform == 'H' and HBO_choice == 'show':
    HBO_shows = df['title'][df['type'] == 'SHOW']
    print('Here is your randomly selected show to watch:')

# %%
if platform == 'H' and HBO_choice == 'show':
    print(HBO_shows.sample())

# %%
if platform == 'H' and HBO_choice == 'movie':
    HBO_movies = df['title'][df['type'] == 'MOVIE']
    print('Here is your randomly selected movie to watch:')

# %%
if platform == 'H' and HBO_choice == 'movie':
    print(HBO_movies.sample())
